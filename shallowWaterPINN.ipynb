# %% [markdown]
# <a href="https://colab.research.google.com/github/abihlo/pinnSWE/blob/main/shallowWaterPINN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyDOE

# %%
import tensorflow as tf
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt

# %%
# Initial condition
u0 = lambda x: 0*x
h0 = lambda x: 1+0.5*np.exp(-20*(x-0.0)**2)

# u0 = lambda x: 0.01*np.sin(np.pi*x+0.5)
# h0 = lambda x: 0.75 + 0.25*np.sin(np.pi*x)

# Boundaries of the computational domain
xleft, xright = -1, 1
t0, tfinal = 0, 2

# Gravitational constant
g = tf.constant(1.0, dtype=tf.float32)

# %%
x = np.linspace(xleft, xright, 100)
plt.plot(x, h0(x))

# %%
# Define the network
inp1 = tf.keras.layers.Input(shape=(1,))
# b1 = tf.keras.layers.BatchNormalization()(inp1)
inp2 = tf.keras.layers.Input(shape=(1,))
# b2 = tf.keras.layers.BatchNormalization()(inp2)
b = tf.keras.layers.Concatenate()([inp1, inp2])
b = tf.keras.layers.Dense(100, activation='tanh')(b)
b = tf.keras.layers.Dense(100, activation='tanh')(b)
b = tf.keras.layers.Dense(100, activation='tanh')(b)
b = tf.keras.layers.Dense(100, activation='tanh')(b)
b = tf.keras.layers.Dense(100, activation='tanh')(b)
b = tf.keras.layers.Dense(100, activation='tanh')(b)
outu = tf.keras.layers.Dense(1, activation='linear')(b)
outh = tf.keras.layers.Dense(1, activation='relu')(b)

model = tf.keras.models.Model([inp1, inp2], [outu, outh])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2)            0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          300         concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          10100       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          10100       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 100)          10100       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          10100       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            101         dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            101         dense_5[0][0]
# ==================================================================================================
# Total params: 51,002
# Trainable params: 51,002
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def PNNtrain(t_bdry, x_bdry, u0, h0, epochs=20000, N_pde=20000, N_iv=1000, N_bv=1000):

  # Optimizer to be used
  opt = tf.keras.optimizers.Adam(
    learning_rate=0.1,
    beta_1=0.99,
    epsilon=1e-1)

  # Sample points where to evaluate the PDE
  tx_min = np.array([t_bdry[0], x_bdry[0]])
  tx_max = np.array([t_bdry[1], x_bdry[1]])  
  pde_points = tx_min + (tx_max - tx_min)*lhs(2, N_pde)
  t_pde = tf.Variable(np.expand_dims(pde_points[:, 0], axis=1)) 
  x_pde = tf.Variable(np.expand_dims(pde_points[:, 1], axis=1))

  # Sample points where to evaluate the initial values
  x_init = np.expand_dims(np.random.uniform(x_bdry[0], x_bdry[1], size=N_iv), axis=1)
  t_init = np.expand_dims(0*x_init, axis=1)
  u_init, h_init = u0(x_init), h0(x_init)

  # Sample points where to evaluate the boundary values
  t_b = np.random.uniform(t_bdry[0], t_bdry[1], size=N_bv)
  t_b = np.expand_dims(np.concatenate((t_b, t_b)), axis=1)
  x_b = np.expand_dims(np.concatenate((x_bdry[0]*np.ones(N_bv),
                           x_bdry[1]*np.ones(N_bv))), axis=1)
 
  # Main training loop
  for i in range(epochs):

    # Outer gradient for tuning network parameters
    with tf.GradientTape() as tape:

      # Inner gradient for derivatives of u wrt x and t
      with tf.GradientTape(persistent=True) as tape2:
        tape2.watch(t_pde)
        tape2.watch(x_pde)
        [u, h] = model([t_pde, x_pde])  
      [dudt, dudx] = tape2.gradient(u, [t_pde, x_pde])
      [dhdt, dhdx] = tape2.gradient(h, [t_pde, x_pde])
      
      # Solve the shallow-water equations
      dudt, dudx = tf.cast(dudt, tf.float32), tf.cast(dudx, tf.float32)
      dhdt, dhdx = tf.cast(dhdt, tf.float32), tf.cast(dhdx, tf.float32)
      
      eqnu = dudt+u*dudx+g*dhdx
      eqnh = dhdt+u*dhdx+h*dudx

      # Define the PDE loss  
      PDEloss = tf.reduce_mean(tf.square(eqnu)) + tf.reduce_mean(tf.square(eqnh))

      # Define the initial and boundary value losses
      [u_init_pred, h_init_pred] = model([t_init, x_init])      
      IVloss = tf.reduce_mean(tf.square(u_init-u_init_pred)) + tf.reduce_mean(tf.square(h_init-h_init_pred))
                              
      [u_b, h_b] = model([t_b, x_b])
      BVloss = tf.reduce_mean(tf.square(u_b[:N_bv]-u_b[N_bv:])) + tf.reduce_mean(tf.square(h_b[:N_bv]-h_b[N_bv:]))

      # Global loss
      loss = PDEloss + IVloss + BVloss

    # Compute the gradient of the global loss wrt the model parameters
    grads = tape.gradient(loss, model.trainable_variables)

    # Gradient step
    opt.apply_gradients(zip(grads, model.trainable_variables))

    if (np.mod(i, 100)==0):
      print("Total loss, PDE loss, IV loss, BV loss in {}th epoch: {: 6.4f}, {: 6.4f}, {: 6.4f}, {: 6.4f}.".format(i, loss.numpy(), PDEloss.numpy(),
                                                                              IVloss.numpy(), BVloss.numpy()))

# %%
PNNtrain([t0, tfinal], [xleft, xright], u0, h0)
# Out:
# Total loss, PDE loss, IV loss, BV loss in 0th epoch:  1.5367,  0.0603,  1.2287,  0.2477.
# Total loss, PDE loss, IV loss, BV loss in 100th epoch:  0.0398,  0.0026,  0.0281,  0.0090.
# Total loss, PDE loss, IV loss, BV loss in 200th epoch:  0.0323,  0.0034,  0.0288,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 300th epoch:  0.0274,  0.0004,  0.0266,  0.0004.
# Total loss, PDE loss, IV loss, BV loss in 400th epoch:  0.0249,  0.0001,  0.0248,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 500th epoch:  0.0249,  0.0001,  0.0247,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 600th epoch:  0.0243,  0.0002,  0.0240,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 700th epoch:  0.0236,  0.0011,  0.0223,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 800th epoch:  0.0221,  0.0009,  0.0210,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 900th epoch:  0.0191,  0.0036,  0.0153,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 1000th epoch:  0.0154,  0.0030,  0.0111,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 1100th epoch:  0.0121,  0.0035,  0.0077,  0.0008.
# Total loss, PDE loss, IV loss, BV loss in 1200th epoch:  0.0096,  0.0035,  0.0049,  0.0011.
# Total loss, PDE loss, IV loss, BV loss in 1300th epoch:  0.0084,  0.0034,  0.0038,  0.0012.
# Total loss, PDE loss, IV loss, BV loss in 1400th epoch:  0.0075,  0.0031,  0.0035,  0.0010.
# Total loss, PDE loss, IV loss, BV loss in 1500th epoch:  0.0069,  0.0031,  0.0026,  0.0012.
# Total loss, PDE loss, IV loss, BV loss in 1600th epoch:  0.0065,  0.0029,  0.0023,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 1700th epoch:  0.0062,  0.0028,  0.0020,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 1800th epoch:  0.0060,  0.0026,  0.0019,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 1900th epoch:  0.0058,  0.0026,  0.0017,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2000th epoch:  0.0057,  0.0026,  0.0017,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2100th epoch:  0.0056,  0.0026,  0.0016,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2200th epoch:  0.0055,  0.0026,  0.0015,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2300th epoch:  0.0054,  0.0026,  0.0015,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2400th epoch:  0.0053,  0.0025,  0.0014,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 2500th epoch:  0.0052,  0.0025,  0.0014,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 2600th epoch:  0.0052,  0.0025,  0.0013,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 2700th epoch:  0.0051,  0.0024,  0.0013,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 2800th epoch:  0.0050,  0.0024,  0.0013,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 2900th epoch:  0.0049,  0.0024,  0.0012,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 3000th epoch:  0.0052,  0.0024,  0.0013,  0.0015.
# Total loss, PDE loss, IV loss, BV loss in 3100th epoch:  0.0068,  0.0031,  0.0018,  0.0019.
# Total loss, PDE loss, IV loss, BV loss in 3200th epoch:  0.0052,  0.0025,  0.0014,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 3300th epoch:  0.0052,  0.0024,  0.0014,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 3400th epoch:  0.0050,  0.0024,  0.0012,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 3500th epoch:  0.0049,  0.0023,  0.0012,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 3600th epoch:  0.0048,  0.0023,  0.0011,  0.0014.
# Total loss, PDE loss, IV loss, BV loss in 3700th epoch:  0.0047,  0.0022,  0.0011,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 3800th epoch:  0.0046,  0.0022,  0.0011,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 3900th epoch:  0.0045,  0.0021,  0.0011,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 4000th epoch:  0.0044,  0.0021,  0.0010,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 4100th epoch:  0.0043,  0.0020,  0.0010,  0.0013.
# Total loss, PDE loss, IV loss, BV loss in 4200th epoch:  0.0042,  0.0020,  0.0010,  0.0012.
# Total loss, PDE loss, IV loss, BV loss in 4300th epoch:  0.0040,  0.0019,  0.0009,  0.0011.
# Total loss, PDE loss, IV loss, BV loss in 4400th epoch:  0.0038,  0.0018,  0.0009,  0.0010.
# Total loss, PDE loss, IV loss, BV loss in 4500th epoch:  0.0036,  0.0018,  0.0008,  0.0009.
# Total loss, PDE loss, IV loss, BV loss in 4600th epoch:  0.0034,  0.0017,  0.0008,  0.0009.
# Total loss, PDE loss, IV loss, BV loss in 4700th epoch:  0.0033,  0.0017,  0.0008,  0.0009.
# Total loss, PDE loss, IV loss, BV loss in 4800th epoch:  0.0032,  0.0016,  0.0007,  0.0009.
# Total loss, PDE loss, IV loss, BV loss in 4900th epoch:  0.0031,  0.0016,  0.0007,  0.0008.
# Total loss, PDE loss, IV loss, BV loss in 5000th epoch:  0.0030,  0.0015,  0.0007,  0.0008.
# Total loss, PDE loss, IV loss, BV loss in 5100th epoch:  0.0029,  0.0015,  0.0007,  0.0007.
# Total loss, PDE loss, IV loss, BV loss in 5200th epoch:  0.0028,  0.0015,  0.0006,  0.0007.
# Total loss, PDE loss, IV loss, BV loss in 5300th epoch:  0.0026,  0.0014,  0.0006,  0.0006.
# Total loss, PDE loss, IV loss, BV loss in 5400th epoch:  0.0025,  0.0014,  0.0006,  0.0006.
# Total loss, PDE loss, IV loss, BV loss in 5500th epoch:  0.0049,  0.0021,  0.0017,  0.0011.
# Total loss, PDE loss, IV loss, BV loss in 5600th epoch:  0.0048,  0.0023,  0.0014,  0.0012.
# Total loss, PDE loss, IV loss, BV loss in 5700th epoch:  0.0037,  0.0018,  0.0010,  0.0008.
# Total loss, PDE loss, IV loss, BV loss in 5800th epoch:  0.0031,  0.0016,  0.0007,  0.0008.
# Total loss, PDE loss, IV loss, BV loss in 5900th epoch:  0.0027,  0.0015,  0.0006,  0.0006.
# Total loss, PDE loss, IV loss, BV loss in 6000th epoch:  0.0025,  0.0013,  0.0006,  0.0006.
# Total loss, PDE loss, IV loss, BV loss in 6100th epoch:  0.0023,  0.0013,  0.0005,  0.0005.
# Total loss, PDE loss, IV loss, BV loss in 6200th epoch:  0.0021,  0.0012,  0.0005,  0.0004.
# Total loss, PDE loss, IV loss, BV loss in 6300th epoch:  0.0020,  0.0012,  0.0004,  0.0004.
# Total loss, PDE loss, IV loss, BV loss in 6400th epoch:  0.0019,  0.0011,  0.0004,  0.0004.
# Total loss, PDE loss, IV loss, BV loss in 6500th epoch:  0.0018,  0.0011,  0.0004,  0.0003.
# Total loss, PDE loss, IV loss, BV loss in 6600th epoch:  0.0017,  0.0010,  0.0004,  0.0003.
# Total loss, PDE loss, IV loss, BV loss in 6700th epoch:  0.0016,  0.0010,  0.0004,  0.0003.
# Total loss, PDE loss, IV loss, BV loss in 6800th epoch:  0.0016,  0.0009,  0.0003,  0.0003.
# Total loss, PDE loss, IV loss, BV loss in 6900th epoch:  0.0015,  0.0009,  0.0003,  0.0003.
# Total loss, PDE loss, IV loss, BV loss in 7000th epoch:  0.0014,  0.0009,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7100th epoch:  0.0014,  0.0009,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7200th epoch:  0.0013,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7300th epoch:  0.0013,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7400th epoch:  0.0013,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7500th epoch:  0.0012,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7600th epoch:  0.0012,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7700th epoch:  0.0012,  0.0008,  0.0003,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7800th epoch:  0.0012,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 7900th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8000th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8100th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8200th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8300th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8400th epoch:  0.0011,  0.0007,  0.0002,  0.0002.
# Total loss, PDE loss, IV loss, BV loss in 8500th epoch:  0.0011,  0.0007,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 8600th epoch:  0.0010,  0.0007,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 8700th epoch:  0.0010,  0.0007,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 8800th epoch:  0.0010,  0.0007,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 8900th epoch:  0.0010,  0.0007,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9000th epoch:  0.0010,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9100th epoch:  0.0010,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9200th epoch:  0.0010,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9300th epoch:  0.0010,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9400th epoch:  0.0010,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9500th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9600th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9700th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9800th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 9900th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10000th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10100th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10200th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10300th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10400th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10500th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10600th epoch:  0.0009,  0.0006,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10700th epoch:  0.0009,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10800th epoch:  0.0009,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 10900th epoch:  0.0009,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11000th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11100th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11200th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11300th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11400th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11500th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11600th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11700th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11800th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 11900th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12000th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12100th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12200th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12300th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12400th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12500th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12600th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12700th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12800th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 12900th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13000th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13100th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13200th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13300th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13400th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13500th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13600th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13700th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13800th epoch:  0.0008,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 13900th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14000th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14100th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14200th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14300th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14400th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14500th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14600th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14700th epoch:  0.0007,  0.0005,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14800th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 14900th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15000th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15100th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15200th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15300th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15400th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15500th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15600th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15700th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15800th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 15900th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16000th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16100th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16200th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16300th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16400th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16500th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16600th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16700th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16800th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 16900th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17000th epoch:  0.0007,  0.0004,  0.0002,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17100th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17200th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17300th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17400th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17500th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17600th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17700th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17800th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 17900th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18000th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18100th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18200th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18300th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18400th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18500th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18600th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18700th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18800th epoch:  0.0007,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 18900th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19000th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19100th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19200th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19300th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19400th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19500th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19600th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19700th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19800th epoch:  0.0006,  0.0004,  0.0001,  0.0001.
# Total loss, PDE loss, IV loss, BV loss in 19900th epoch:  0.0006,  0.0004,  0.0001,  0.0001.

# %%
# Grid where to evaluate the model
m, n = 500, 500
t = np.linspace(t0, tfinal, m)
x = np.linspace(xleft, xright, n)
T, X = np.meshgrid(t, x)

dt = t[1]-t[0]

[u, h] = model([np.expand_dims(T.flatten(), axis=1), 
           np.expand_dims(X.flatten(), axis=1)])
u, h = np.reshape(u, (m, n)), np.reshape(h, (m, n))

# %%
plt.contourf(X, T, h, 100, cmap=plt.cm.coolwarm)
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()

# %%
plot_steps = [0, 100, 200, 300, 400]
for i in plot_steps:
  plt.plot(x, h[:,i],'k')
plt.title('Solution at time step {}'.format(plot_steps))
plt.xlabel('x')
plt.ylabel('h')
plt.grid()
